# %%
import requests

# Paste the "Your Access Token" from your Strava API page here
ACCESS_TOKEN = '8ed1581fa1f6396a12bbc1a3edb8764fd6080a79'

# The endpoint for the authenticated athlete (you)
url = "https://www.strava.com/api/v3/athlete"

headers = {
    "Authorization": f"Bearer {ACCESS_TOKEN}"
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    print("✅ Strava OAuth2 Connection Successful!")
    data = response.json()
    print(f"Connected to account: {data.get('firstname')} {data.get('lastname')}")
else:
    print(f"❌ Connection Failed. Status Code: {response.status_code}")
    print(response.json())
